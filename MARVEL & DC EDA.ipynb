# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sea

# %%
marvel = pd.read_csv(r'C:\Users\Lenovo\Desktop\Marvel-Project\charcters_stats.csv')
marvel
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
marvel.shape
# Out:
# (611, 9)

# %%
#5 VALUES FROM THE TOP
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
#CHARACTER TYPES
marvel['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
#ONLY PROTAGINIST
good = marvel[marvel['Alignment']=='good']
good
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
#ONLY ANTAGONISTS
bad = marvel[marvel['Alignment']=='bad']
bad
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# ...

# %%
#GOOD CHARACTERS ACCORDING TO THEIR SPEED
good.sort_values(by = 'Speed', ascending = False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
# ..              ...       ...           ...       ...    ...         ...
# 280       Hellstorm      good             1         1      1           1
# 445         Quantum      good             1         1      1           1
# 277   Hawkwoman III      good             1         1      1           1
# 276    Hawkwoman II      good             1         1      1           1
# 405           Namor      good             1         1      1           1
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# ...

# %%
#BAD CHARACTERS ACCORDING TO THEIR SPEED
bad.sort_values(by = 'Speed',ascending = False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610             Zoom       bad            50        10    100          28
# 11        Air-Walker       bad            50        85    100          85
# 16             Amazo       bad            75       100    100         100
# 535   Superboy-Prime       bad            94       100    100         100
# 242      General Zod       bad            94       100     96         100
# ..               ...       ...           ...       ...    ...         ...
# 256  Granny Goodness       bad             1         1      1           1
# 254      Goliath III       bad             1         1      1           1
# 503         Siren II       bad             1         1      1           1
# 154      Cheetah III       bad             1         1      1           1
# 153       Cheetah II       bad             1         1      1           1
#
#      Power  Combat  Total
# 610     72      28    288
# ...

# %%
#GOOD CHARACTERS ACCORDING THEIR POWER
good.sort_values( by = 'Power' , ascending = False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609         Zatanna      good            75        10     23          28
# 546            Thor      good            69       100     92         100
# 511           Spawn      good            75        60     50          90
# 69    Beta Ray Bill      good            63        80     35          95
# 70         Beyonder      good            88       100     23         100
# ..              ...       ...           ...       ...    ...         ...
# 127       Bumbleboy      good             1         1      1           1
# 124  Brother Voodoo      good             1         1      1           1
# 415     Nite Owl II      good             1         1      1           1
# 120         Box III      good             1         1      1           1
# 100     Blaquesmith      good             1         1      1           1
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# ...

# %%
good.sort_values( by = 'Power' , ascending = False).head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %%
#PLOTTING A BAR-PLOT OF TOP 5 MOST POWER CHARACTERS
sea.set(style = 'whitegrid')
sea.barplot (x= 'Name', y = 'Power' , data =good.sort_values( by = 'Power' , ascending = False).head() )
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Power'>

# %%
#GOOD CHARACTERS HAVING THE MAX POWER
max = good[good['Power']==100]
max
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %%
max.shape
# Out:
# (33, 9)

# %%
#OVERALL STRONGEST CHARACTERS
strong = marvel.sort_values(by = 'Total', ascending = False)
strong
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 242        General Zod       bad            94       100     96         100
# 535     Superboy-Prime       bad            94       100    100         100
# 537           Superman      good           100       100    100         100
# 16               Amazo       bad            75       100    100         100
# ..                 ...       ...           ...       ...    ...         ...
# 462       Renata Soliz      good             1         1      1           1
# 137   Captain Mar-vell      good             1         1      1           1
# 136       Captain Epic      good             1         1      1           1
# 466            Ripcord      good             1         1      1           1
# 335   Lady Deathstrike       bad             1         1      1           1
#
#      Power  Combat  Total
# 361    100      85    581
# ...

# %%
strong.loc[:,('Name' , 'Total')]
# Out:
#                   Name  Total
# 361  Martian Manhunter    581
# 242        General Zod    579
# 535     Superboy-Prime    579
# 537           Superman    579
# 16               Amazo    575
# ..                 ...    ...
# 462       Renata Soliz      5
# 137   Captain Mar-vell      5
# 136       Captain Epic      5
# 466            Ripcord      5
# 335   Lady Deathstrike      5
#
# [611 rows x 2 columns]

# %%
strong.head()
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 242        General Zod       bad            94       100     96         100
# 535     Superboy-Prime       bad            94       100    100         100
# 537           Superman      good           100       100    100         100
# 16               Amazo       bad            75       100    100         100
#
#      Power  Combat  Total
# 361    100      85    581
# 242     94      95    579
# 535    100      85    579
# 537     94      85    579
# 16     100     100    575

# %%
#PLOTTING A BAR PLOT TOP 5 STRONGEST CHARACTERS
plt.figure(figsize = (12,6))
sea.barplot(x='Name' , y='Total' , data = strong.head() )
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Total'>

# %%
#BAD CHARACTERS ACCORDING TO THEIR INTELLIGENCE LEVEL
bad.sort_values(by = 'Intelligence' ,ascending = False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# ..               ...       ...           ...       ...    ...         ...
# 460      Redeemer II       bad             1         1      1           1
# 154      Cheetah III       bad             1         1      1           1
# 153       Cheetah II       bad             1         1      1           1
# 152        Cheetah I       bad             1         1      1           1
# 461     Redeemer III       bad             1         1      1           1
#
#      Power  Combat  Total
# 386    100      28    277
# ...

# %%
bad.sort_values(by = 'Intelligence' ,ascending = False).head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
#
#      Power  Combat  Total
# 386    100      28    277
# 338     10      28    174
# 336     58      42    236
# 122     60      75    416
# 194     93      84    429

# %%
marvel.iloc[0:10,:]
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0       3-D Man      good            50        31     43          32     25
# 1        A-Bomb      good            38       100     17          80     17
# 2    Abe Sapien      good            88        14     35          42     35
# 3      Abin Sur      good            50        90     53          64     84
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 6   Adam Monroe      good            63        10     12         100     71
# 7  Adam Strange      good             1         1      1           1      0
# 8     Agent  13      good             1         1      1           1      0
# 9     Agent Bob      good            10         8     13           5      5
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436
# 5      56    526
# ...

# %%
plt.figure(figsize = (15,5))
sea.scatterplot(x='Name' , y='Total' , data=marvel.iloc[0:10,:] , hue = 'Alignment')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Total'>

# %%
#MAKING A HISTOGRAM FOR SPEED OF GOOD CHARACTERS
plt.figure(figsize = (10,5))
sea.distplot(good['Speed'],kde = False)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Speed'>

# %%
#MAKING A DISTPLOT FOR VILLAIN FOR COMBAT
plt.figure(figsize = (10,5))
sea.distplot(bad['Combat'],hist = False)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Combat', ylabel='Density'>

# %%
plt.figure(figsize = (10,5))
sea.distplot(bad['Combat'],kde = False)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Combat'>

# %%
#A PAIR PLOT FOR GOOD CHARACTERS
sea.pairplot(good)

# %%
#A PAIR PLOT FOR BAD CHARACTERS
sea.pairplot(bad)
